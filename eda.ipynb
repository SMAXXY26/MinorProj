# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("predictive_maintenance.csv")
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
print(df['Target'].unique())
y=df['Target']
# Out:
# [0 1]

# %% [markdown]
# ### Feature Selection ###

# %%
X=df.iloc[:,3:8]

# %%
X.head()
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                298.1                    308.6                    1551
# 1                298.2                    308.7                    1408
# 2                298.1                    308.5                    1498
# 3                298.2                    308.6                    1433
# 4                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]
# 0         42.8                0
# 1         46.3                3
# 2         49.4                5
# 3         39.5                7
# 4         40.0                9

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Target, dtype: int64

# %% [markdown]
# ### EDA ###

# %%
corr_matrix = X.corr()

#Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# Basic scatter plot
plt.scatter(df['Target'],df['Process temperature [K]'])

# Essential "Make it readable" commands
plt.title('Target V process temp')
plt.xlabel('Target')
plt.ylabel('Temprature')

# The "Show me the money" command
plt.show()

# %%
# Create the histogram
plt.hist(df, bins=20, color='skyblue', edgecolor='black')

# Add labels
plt.title('Basic Histogram')
plt.xlabel('Values')
plt.ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Create the histogram
# ----> 2 plt.hist(df, bins=30, color='skyblue', edgecolor='black')
#       4 # Add labels
#       5 plt.title('Basic Histogram')
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/pyplot.py:3478, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3453 @_copy_docstring_and_deprecators(Axes.hist)
#    3454 def hist(
#    3455     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3476     BarContainer | Polygon | list[BarContainer | Polygon],
#    3477 ]:
# -> 3478     return gca().hist(
#    3479         x,
#    3480         bins=bins,
#    3481         range=range,
#    3482         density=density,
#    3483         weights=weights,
#    3484         cumulative=cumulative,
#    3485         bottom=bottom,
#    3486         histtype=histtype,
#    3487         align=align,
#    3488         orientation=orientation,
#    3489         rwidth=rwidth,
#    3490         log=log,
#    3491         color=color,
#    3492         label=label,
#    3493         stacked=stacked,
#    3494         **({"data": data} if data is not None else {}),
#    3495         **kwargs,
#    3496     )
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:7053, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7051 if orientation == "vertical":
#    7052     convert_units = self.convert_xunits
# -> 7053     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    7054          *map(convert_units, x[1:])]
#    7055 else:  # horizontal
#    7056     convert_units = self.convert_yunits
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/artist.py:278, in Artist.convert_xunits(self, x)
#     276 if ax is None or ax.xaxis is None:
#     277     return x
# --> 278 return ax.xaxis.convert_units(x)
#
# File ~/Minor project/.venv/lib/python3.13/site-packages/matplotlib/axis.py:1813, in Axis.convert_units(self, x)
#    1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
# -> 1813     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1814                                  f'units: {x!r}') from e
#    1815 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['M14860', 'L47181', 'L47182', ..., 'M24857', 'H39412', 'M24859'],
#       shape=(10000,), dtype=object)
